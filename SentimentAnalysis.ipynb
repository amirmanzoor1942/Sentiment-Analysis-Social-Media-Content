# %%
#Import required packages
import pandas as pd
import nltk
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load structured dataset
df_structured = pd.read_csv('social_media_sentiment_data.csv')

# %%
# Load unstructured dataset
df_unstructured = pd.read_csv('unstructured_sentiment_data.csv')

# %%
# Combine datasets
df_combined = df_structured.merge(df_unstructured, on='Post Id', how='left')

# %%
# Perform sentiment analysis on comments
def analyze_sentiment(comment):
    analysis = TextBlob(str(comment))
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df_combined['Sentiment'] = df_combined['Comments'].apply(analyze_sentiment)

# %%
# Visualize the results
plt.figure(figsize=(8, 5))
sns.countplot(x='Sentiment', data=df_combined, palette='coolwarm')
plt.title("Sentiment Analysis of Social Media Comments")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\engrd\AppData\Local\Temp\ipykernel_8428\1042930813.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment', data=df_combined, palette='coolwarm')

# %%
# Save the processed data
df_combined.to_csv('processed_combined_sentiment_data.csv', index=False)

# %%
print("Sentiment analysis complete. Processed data saved.")
# Out:
# Sentiment analysis complete. Processed data saved.
